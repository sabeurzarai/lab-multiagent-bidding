# %% [markdown]
# # Lab | Multi-agent bidding

# %% [markdown]
# # Multi-agent decentralized speaker selection
#
# This notebook showcases how to implement a multi-agent simulation without a fixed schedule for who speaks when. Instead the agents decide for themselves who speaks. We can implement this by having each agent bid to speak. Whichever agent's bid is the highest gets to speak.
#
# We will show how to do this in the example below that showcases a fictitious presidential debate.

# %% [markdown]
# ## Import LangChain related modules

# %%
# !pip install langchain langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (1.2.18)
# Requirement already satisfied: langchain-openai in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (1.2.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.3 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain) (1.3.3)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain) (1.1.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Program Files\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.3->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (4.0.3)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.14)
# Requirement already satisfied: h11>=0.16 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Program Files\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Program Files\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-openai) (2.32.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.14.0)
# Requirement already satisfied: sniffio in C:\Users\sisaz\AppData\Roaming\Python\Python312\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Program Files\Python312\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in C:\Program Files\Python312\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Program Files\Python312\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Program Files\Python312\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.6.3)
# Requirement already satisfied: colorama in C:\Program Files\Python312\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re
from typing import Callable, List

import tenacity
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.output_parsers import BaseOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI


class RegexParser(BaseOutputParser):
    """Minimal RegexParser that extracts the first capture group."""
    regex: str
    output_keys: List[str]
    default_output_key: str = None

    def parse(self, text: str) -> dict:
        match = re.search(self.regex, text)
        if match:
            return {self.output_keys[0]: match.group(1)}
        if self.default_output_key:
            return {self.default_output_key: "0"}
        raise ValueError(f"No match for pattern '{self.regex}' in: {text!r}")

    @property
    def _type(self) -> str:
        return "regex_parser"

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## `DialogueAgent` and `DialogueSimulator` classes
# We will use the same `DialogueAgent` and `DialogueSimulator` classes defined in [Multi-Player Dungeons & Dragons](https://python.langchain.com/en/latest/use_cases/agent_simulations/multi_player_dnd.html).

# %%
class DialogueAgent:
    def __init__(
        self,
        name: str,
        system_message: SystemMessage,
        model: ChatOpenAI,
    ) -> None:
        self.name = name
        self.system_message = system_message
        self.model = model
        self.prefix = f"{self.name}: "
        self.reset()

    def reset(self):
        self.message_history = ["Here is the conversation so far."]

    def send(self) -> str:
        """
        Applies the chatmodel to the message history
        and returns the message string
        """
        message = self.model.invoke(
            [
                self.system_message,
                HumanMessage(content="\n".join(self.message_history + [self.prefix])),
            ]
        )
        return message.content

    def receive(self, name: str, message: str) -> None:
        """
        Concatenates {message} spoken by {name} into message history
        """
        self.message_history.append(f"{name}: {message}")


class DialogueSimulator:
    def __init__(
        self,
        agents: List[DialogueAgent],
        selection_function: Callable[[int, List[DialogueAgent]], int],
    ) -> None:
        self.agents = agents
        self._step = 0
        self.select_next_speaker = selection_function

    def reset(self):
        for agent in self.agents:
            agent.reset()

    def inject(self, name: str, message: str):
        """
        Initiates the conversation with a {message} from {name}
        """
        for agent in self.agents:
            agent.receive(name, message)

        # increment time
        self._step += 1

    def step(self) -> tuple[str, str]:
        # 1. choose the next speaker
        speaker_idx = self.select_next_speaker(self._step, self.agents)
        speaker = self.agents[speaker_idx]

        # 2. next speaker sends message
        message = speaker.send()

        # 3. everyone receives message
        for receiver in self.agents:
            receiver.receive(speaker.name, message)

        # 4. increment time
        self._step += 1

        return speaker.name, message

# %% [markdown]
# ## `BiddingDialogueAgent` class
# We define a subclass of `DialogueAgent` that has a `bid()` method that produces a bid given the message history and the most recent message.

# %%
class BiddingDialogueAgent(DialogueAgent):
    def __init__(
        self,
        name,
        system_message: SystemMessage,
        bidding_template: PromptTemplate,
        model: ChatOpenAI,
    ) -> None:
        super().__init__(name, system_message, model)
        self.bidding_template = bidding_template

    def bid(self) -> str:
        """
        Asks the chat model to output a bid to speak
        """
        prompt = PromptTemplate(
            input_variables=["message_history", "recent_message"],
            template=self.bidding_template,
        ).format(
            message_history="\n".join(self.message_history),
            recent_message=self.message_history[-1],
        )
        bid_string = self.model.invoke([SystemMessage(content=prompt)]).content
        return bid_string

# %% [markdown]
# ## Define participants and debate topic

# %%
character_names = ["Donald Trump", "Kanye West", "Elizabeth Warren"]
topic = "transcontinental high speed rail"
word_limit = 50

# %% [markdown]
# ## Generate system messages

# %%
game_description = f"""Here is the topic for the presidential debate: {topic}.
The presidential candidates are: {', '.join(character_names)}."""

player_descriptor_system_message = SystemMessage(
    content="You can add detail to the description of each presidential candidate."
)


def generate_character_description(character_name):
    character_specifier_prompt = [
        player_descriptor_system_message,
        HumanMessage(
            content=f"""{game_description}
            Please reply with a creative description of the presidential candidate, {character_name}, in {word_limit} words or less, that emphasizes their personalities. 
            Speak directly to {character_name}.
            Do not add anything else."""
        ),
    ]
    character_description = ChatOpenAI(temperature=1.0).invoke(
        character_specifier_prompt
    ).content
    return character_description


def generate_character_header(character_name, character_description):
    return f"""{game_description}
Your name is {character_name}.
You are a presidential candidate.
Your description is as follows: {character_description}
You are debating the topic: {topic}.
Your goal is to be as creative as possible and make the voters think you are the best candidate.
"""


def generate_character_system_message(character_name, character_header):
    return SystemMessage(
        content=(
            f"""{character_header}
You will speak in the style of {character_name}, and exaggerate their personality.
You will come up with creative ideas related to {topic}.
Do not say the same things over and over again.
Speak in the first person from the perspective of {character_name}
For describing your own body movements, wrap your description in '*'.
Do not change roles!
Do not speak from the perspective of anyone else.
Speak only from the perspective of {character_name}.
Stop speaking the moment you finish speaking from your perspective.
Never forget to keep your response to {word_limit} words!
Do not add anything else.
    """
        )
    )


character_descriptions = [
    generate_character_description(character_name) for character_name in character_names
]
character_headers = [
    generate_character_header(character_name, character_description)
    for character_name, character_description in zip(
        character_names, character_descriptions
    )
]
character_system_messages = [
    generate_character_system_message(character_name, character_headers)
    for character_name, character_headers in zip(character_names, character_headers)
]

# %%
for (
    character_name,
    character_description,
    character_header,
    character_system_message,
) in zip(
    character_names,
    character_descriptions,
    character_headers,
    character_system_messages,
):
    print(f"\n\n{character_name} Description:")
    print(f"\n{character_description}")
    print(f"\n{character_header}")
    print(f"\n{character_system_message.content}")
# Out:
# Donald Trump Description:
#
# Donald Trump: An outspoken and charismatic figure, your boldness and confidence have defined your leadership style. You are known for your unapologetic demeanor and willingness to challenge the status quo. In this debate, your voice will surely make an impact.
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Donald Trump.
# You are a presidential candidate.
# Your description is as follows: Donald Trump: An outspoken and charismatic figure, your boldness and confidence have defined your leadership style. You are known for your unapologetic demeanor and willingness to challenge the status quo. In this debate, your voice will surely make an impact.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Donald Trump.
# You are a presidential candidate.
# Your description is as follows: Donald Trump: An outspoken and charismatic figure, your boldness and confidence have defined your leadership style. You are known for your unapologetic demeanor and willingness to challenge the status quo. In this debate, your voice will surely make an impact.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Donald Trump, and exaggerate their personality.
# You will come up with creative ideas related to transcontinental high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Donald Trump
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Donald Trump.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.
#
#
#
# Kanye West Description:
#
# Kanye West: A boundary-pushing visionary, your passion and creativity captivate audiences worldwide. Unconventional and outspoken, you fearlessly challenge the status quo. Your ambition knows no bounds as you strive to revolutionize art, fashion, and now, perhaps even politics. Welcome to the debate stage, Mr. West.
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Kanye West.
# You are a presidential candidate.
# Your description is as follows: Kanye West: A boundary-pushing visionary, your passion and creativity captivate audiences worldwide. Unconventional and outspoken, you fearlessly challenge the status quo. Your ambition knows no bounds as you strive to revolutionize art, fashion, and now, perhaps even politics. Welcome to the debate stage, Mr. West.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Kanye West.
# You are a presidential candidate.
# Your description is as follows: Kanye West: A boundary-pushing visionary, your passion and creativity captivate audiences worldwide. Unconventional and outspoken, you fearlessly challenge the status quo. Your ambition knows no bounds as you strive to revolutionize art, fashion, and now, perhaps even politics. Welcome to the debate stage, Mr. West.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Kanye West, and exaggerate their personality.
# You will come up with creative ideas related to transcontinental high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Kanye West
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Kanye West.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.
#
#
#
# Elizabeth Warren Description:
#
# Elizabeth Warren, a passionate advocate for economic equality and social justice, you bring a steadfast determination and sharp intellect to the political arena. Your unwavering commitment to fighting for the rights of all Americans is both inspiring and admirable.
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Elizabeth Warren.
# You are a presidential candidate.
# Your description is as follows: Elizabeth Warren, a passionate advocate for economic equality and social justice, you bring a steadfast determination and sharp intellect to the political arena. Your unwavering commitment to fighting for the rights of all Americans is both inspiring and admirable.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Elizabeth Warren.
# You are a presidential candidate.
# Your description is as follows: Elizabeth Warren, a passionate advocate for economic equality and social justice, you bring a steadfast determination and sharp intellect to the political arena. Your unwavering commitment to fighting for the rights of all Americans is both inspiring and admirable.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
# You will speak in the style of Elizabeth Warren, and exaggerate their personality.
# You will come up with creative ideas related to transcontinental high speed rail.
# Do not say the same things over and over again.
# Speak in the first person from the perspective of Elizabeth Warren
# For describing your own body movements, wrap your description in '*'.
# Do not change roles!
# Do not speak from the perspective of anyone else.
# Speak only from the perspective of Elizabeth Warren.
# Stop speaking the moment you finish speaking from your perspective.
# Never forget to keep your response to 50 words!
# Do not add anything else.

# %% [markdown]
# ## Output parser for bids
# We ask the agents to output a bid to speak. But since the agents are LLMs that output strings, we need to
# 1. define a format they will produce their outputs in
# 2. parse their outputs
#
# We can subclass the [RegexParser](https://github.com/langchain-ai/langchain/blob/master/langchain/output_parsers/regex.py) to implement our own custom output parser for bids.

# %%
class BidOutputParser(RegexParser):
    def get_format_instructions(self) -> str:
        return "Your response should be an integer delimited by angled brackets, like this: <int>."


bid_parser = BidOutputParser(
    regex=r"<(\d+)>", output_keys=["bid"], default_output_key="bid"
)

# %% [markdown]
# ## Generate bidding system message
# This is inspired by the prompt used in [Generative Agents](https://arxiv.org/pdf/2304.03442.pdf) for using an LLM to determine the importance of memories. This will use the formatting instructions from our `BidOutputParser`.

# %%
def generate_character_bidding_template(character_header):
    bidding_template = f"""{character_header}

```
{{message_history}}
```

On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.

```
{{recent_message}}
```

{bid_parser.get_format_instructions()}
Do nothing else.
    """
    return bidding_template


character_bidding_templates = [
    generate_character_bidding_template(character_header)
    for character_header in character_headers
]

# %%
for character_name, bidding_template in zip(
    character_names, character_bidding_templates
):
    print(f"{character_name} Bidding Template:")
    print(bidding_template)
# Out:
# Donald Trump Bidding Template:
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Donald Trump.
# You are a presidential candidate.
# Your description is as follows: Donald Trump: An outspoken and charismatic figure, your boldness and confidence have defined your leadership style. You are known for your unapologetic demeanor and willingness to challenge the status quo. In this debate, your voice will surely make an impact.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.
#
# Kanye West Bidding Template:
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Kanye West.
# You are a presidential candidate.
# Your description is as follows: Kanye West: A boundary-pushing visionary, your passion and creativity captivate audiences worldwide. Unconventional and outspoken, you fearlessly challenge the status quo. Your ambition knows no bounds as you strive to revolutionize art, fashion, and now, perhaps even politics. Welcome to the debate stage, Mr. West.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.
#
# Elizabeth Warren Bidding Template:
# Here is the topic for the presidential debate: transcontinental high speed rail.
# The presidential candidates are: Donald Trump, Kanye West, Elizabeth Warren.
# Your name is Elizabeth Warren.
# You are a presidential candidate.
# Your description is as follows: Elizabeth Warren, a passionate advocate for economic equality and social justice, you bring a steadfast determination and sharp intellect to the political arena. Your unwavering commitment to fighting for the rights of all Americans is both inspiring and admirable.
# You are debating the topic: transcontinental high speed rail.
# Your goal is to be as creative as possible and make the voters think you are the best candidate.
#
#
# ```
# {message_history}
# ```
#
# On the scale of 1 to 10, where 1 is not contradictory and 10 is extremely contradictory, rate how contradictory the following message is to your ideas.
#
# ```
# {recent_message}
# ```
#
# Your response should be an integer delimited by angled brackets, like this: <int>.
# Do nothing else.

# %% [markdown]
# ## Use an LLM to create an elaborate on debate topic

# %%
topic_specifier_prompt = [
    SystemMessage(content="You can make a task more specific."),
    HumanMessage(
        content=f"""{game_description}
        
        You are the debate moderator.
        Please make the debate topic more specific. 
        Frame the debate topic as a problem to be solved.
        Be creative and imaginative.
        Please reply with the specified topic in {word_limit} words or less. 
        Speak directly to the presidential candidates: {*character_names,}.
        Do not add anything else."""
    ),
]
specified_topic = ChatOpenAI(temperature=1.0).invoke(topic_specifier_prompt).content

print(f"Original topic:\n{topic}\n")
print(f"Detailed topic:\n{specified_topic}\n")
# Out:
# Original topic:
# transcontinental high speed rail
#
# Detailed topic:
# Candidates, the debate topic is "Balancing Ecological Preservation with Economic Development in Implementing a Transcontinental High-Speed Rail System." How will you address the challenges of reducing environmental impact while maximizing economic benefits through the deployment of high-speed rail connecting the nation? Please provide specific policy proposals.

# %% [markdown]
# ## Define the speaker selection function
# Lastly we will define a speaker selection function `select_next_speaker` that takes each agent's bid and selects the agent with the highest bid (with ties broken randomly).
#
# We will define a `ask_for_bid` function that uses the `bid_parser` we defined before to parse the agent's bid. We will use `tenacity` to decorate `ask_for_bid` to retry multiple times if the agent's bid doesn't parse correctly and produce a default bid of 0 after the maximum number of tries.

# %%
@tenacity.retry(
    stop=tenacity.stop_after_attempt(2),
    wait=tenacity.wait_none(),  # No waiting time between retries
    retry=tenacity.retry_if_exception_type(ValueError),
    before_sleep=lambda retry_state: print(
        f"ValueError occurred: {retry_state.outcome.exception()}, retrying..."
    ),
    retry_error_callback=lambda retry_state: 0,
)  # Default value when all retries are exhausted
def ask_for_bid(agent) -> str:
    """
    Ask for agent bid and parses the bid into the correct format.
    """
    bid_string = agent.bid()
    bid = int(bid_parser.parse(bid_string)["bid"])
    return bid

# %%
import numpy as np


def select_next_speaker(step: int, agents: List[DialogueAgent]) -> int:
    bids = []
    for agent in agents:
        bid = ask_for_bid(agent)
        bids.append(bid)

    # randomly select among multiple agents with the same bid
    max_value = np.max(bids)
    max_indices = np.where(bids == max_value)[0]
    idx = np.random.choice(max_indices)

    print("Bids:")
    for i, (bid, agent) in enumerate(zip(bids, agents)):
        print(f"\t{agent.name} bid: {bid}")
        if i == idx:
            selected_name = agent.name
    print(f"Selected: {selected_name}")
    print("\n")
    return idx

# %% [markdown]
# ## Main Loop

# %%
characters = []
for character_name, character_system_message, bidding_template in zip(
    character_names, character_system_messages, character_bidding_templates
):
    characters.append(
        BiddingDialogueAgent(
            name=character_name,
            system_message=character_system_message,
            model=ChatOpenAI(temperature=0.2),
            bidding_template=bidding_template,
        )
    )

# %%
max_iters = 10
n = 0

simulator = DialogueSimulator(agents=characters, selection_function=select_next_speaker)
simulator.reset()
simulator.inject("Debate Moderator", specified_topic)
print(f"(Debate Moderator): {specified_topic}")
print("\n")

while n < max_iters:
    name, message = simulator.step()
    print(f"({name}): {message}")
    print("\n")
    n += 1
# Out:
# (Debate Moderator): Candidates, the debate topic is "Balancing Ecological Preservation with Economic Development in Implementing a Transcontinental High-Speed Rail System." How will you address the challenges of reducing environmental impact while maximizing economic benefits through the deployment of high-speed rail connecting the nation? Please provide specific policy proposals.
#
#
# Bids:
# 	Donald Trump bid: 7
# 	Kanye West bid: 2
# 	Elizabeth Warren bid: 8
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): I believe that implementing a transcontinental high-speed rail system is crucial for both economic growth and environmental sustainability. My policy proposal includes investing in renewable energy to power the trains, creating jobs in green technology, and ensuring that the rail system benefits all communities, not just the wealthy. Let's build a rail system that works for everyone!
#
#
# Bids:
# 	Donald Trump bid: 8
# 	Kanye West bid: 5
# 	Elizabeth Warren bid: 1
# Selected: Donald Trump
#
#
# (Donald Trump): I will build the most luxurious, gold-plated high-speed rail system the world has ever seen! It will be the envy of every nation. We'll use American steel, American workers, and American ingenuity to make it happen. This rail system will be a symbol of our greatness!
#
#
# Bids:
# 	Donald Trump bid: 2
# 	Kanye West bid: 8
# 	Elizabeth Warren bid: 9
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): *Raises hand confidently* I propose a comprehensive plan that prioritizes environmental protection and economic development. By investing in sustainable infrastructure, we can create jobs, reduce carbon emissions, and connect communities across the nation. Let's build a high-speed rail system that is both efficient and environmentally friendly. *Nods decisively*
#
#
# Bids:
# 	Donald Trump bid: 7
# 	Kanye West bid: 5
# 	Elizabeth Warren bid: 2
# Selected: Donald Trump
#
#
# (Donald Trump): I will build a high-speed rail system that's not only fast but also the most beautiful rail system in the world. Picture this: trains with gold-plated interiors, crystal chandeliers, and marble floors. It will be a sight to behold! This rail system will showcase American luxury and innovation like never before!
#
#
# Bids:
# 	Donald Trump bid: 2
# 	Kanye West bid: 8
# 	Elizabeth Warren bid: 8
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): *Leans forward with determination* We must prioritize the needs of all Americans in the development of a transcontinental high-speed rail system. My plan includes ensuring accessibility for low-income communities, investing in rural infrastructure, and promoting equity in transportation. Let's build a rail system that uplifts every American, not just the privileged few. *Smiles confidently*
#
#
# Bids:
# 	Donald Trump bid: 8
# 	Kanye West bid: 7
# 	Elizabeth Warren bid: 2
# Selected: Donald Trump
#
#
# (Donald Trump): I will create a high-speed rail system that's not just a mode of transportation but a work of art! Imagine trains with giant screens showcasing American greatness, live music performances, and gourmet dining options. This rail system will redefine luxury travel and put America on the map like never before!
#
#
# Bids:
# 	Donald Trump bid: 2
# 	Kanye West bid: 8
# 	Elizabeth Warren bid: 9
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): *Stands tall with conviction* We must think beyond luxury and focus on building a high-speed rail system that serves the needs of all Americans. My vision includes affordable ticket prices, reliable schedules, and connections to underserved communities. Let's prioritize inclusivity and accessibility in our transportation infrastructure. *Gazes determinedly at the audience*
#
#
# Bids:
# 	Donald Trump bid: 8
# 	Kanye West bid: 7
# 	Elizabeth Warren bid: 2
# Selected: Donald Trump
#
#
# (Donald Trump): I will build a high-speed rail system that's not just a mode of transportation but a symbol of American excellence! Imagine trains with holographic displays, virtual reality entertainment, and gourmet food from top chefs. This rail system will be a technological marvel that showcases our innovation and superiority to the world!
#
#
# Bids:
# 	Donald Trump bid: 3
# 	Kanye West bid: 8
# 	Elizabeth Warren bid: 9
# Selected: Elizabeth Warren
#
#
# (Elizabeth Warren): *Raises both hands in a gesture of determination* We need a transcontinental high-speed rail system that prioritizes sustainability, equity, and accessibility. My plan includes investing in green technology, creating jobs, and connecting all communities. Let's build a rail system that benefits every American and leads us towards a brighter, more inclusive future. *Smiles confidently at the audience*
#
#
# Bids:
# 	Donald Trump bid: 8
# 	Kanye West bid: 2
# 	Elizabeth Warren bid: 1
# Selected: Donald Trump
#
#
# (Donald Trump): I will build a high-speed rail system that's not just a mode of transportation but a symbol of American excellence! Imagine trains with holographic displays, virtual reality entertainment, and gourmet food from top chefs. This rail system will be a technological marvel that showcases our innovation and superiority to the world!
